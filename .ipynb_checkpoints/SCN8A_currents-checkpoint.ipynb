# %%
import optimize_na_ga_v2 as opt
import numpy as np
import time
import generalized_genSim_shorten_time as ggsd
from neuron import h, gui
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx
from scipy import optimize, stats
import bluepyopt as bpop
import bluepyopt.deapext.algorithms as algo
import vclamp_evaluator as vcl_ev
import pickle
import time
import numpy as np
from deap import tools
import random
from deap import base, creator
import multiprocessing
import eval_helper as eh
#import scoring_functions as sf

# %%
#Changing Parametes for Wild Type
eh.change_params([26.16290131186328, -12.0101639601674, 27.196053413117404, 1.9469861884994089, 30.39306382908601, 0.0017907215184697748, 23.785261506905094, 4.92857518968744, -26.241045324281977, 8.086106428222955, 26.222313051782375, 2.5274060622463557, 0.16975232812307933, 12.616856862863338, 38.90427040109758, 23.1201609106394, -51.93850700235751, -59.251307951503705, -35.96725564810401, -42.12510135698245, 31.930246378525663, -65.11348041971499, -59.37453417493945, 27.768467864639433], False)

# %%
#Setting variables for activation of wild type
conductance, domain, all_is = ggsd.activationNa12("genActivation")
t_vec = ggsd.activationNa12("getTimesteps")
print(len(all_is))
print(len(all_is[0]))
print(len(t_vec))

times = []
for i in range(1,2800):
    times.append(t_vec[i])
# Out:
# 11
# 2799
# 2800

# %%
# Plots activation for wild type
plt.figure(dpi=150)
x_ticks = np.arange(0, 70, 5)
plt.xticks(x_ticks)
y_ticks = np.arange(-0.6, 0, 0.05)
plt.yticks(y_ticks)
for i in range(11):
    plt.plot(times, all_is[i])
plt.title('SCN8A Wild Type, Activation')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[1])
plt.title('SCN8A Wild Type, Activation -70 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[2])
plt.title('SCN8A Wild Type, Activation -60 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[3])
plt.title('SCN8A Wild Type, Activation -50 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[4])
plt.title('SCN8A Wild Type, Activation -40 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[5])
plt.title('SCN8A Wild Type, Activation -30 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[6])
plt.title('SCN8A Wild Type, Activation -20 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[7])
plt.title('SCN8A Wild Type, Activation -10 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[8])
plt.title('SCN8A Wild Type, Activation 0 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[9])
plt.title('SCN8A Wild Type, Activation 10 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[10])
plt.title('SCN8A Wild Type, Activation 20 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
# Setting parameters for mutant
eh.change_params([84.84985991178564, -10.649745665278218, 18.94182073634545, 11.684636394881158, 23.956047692506168, 0.0017500368848982794, 8.018375873536707, 4.2822273182838835, -4.36607995239862, 9.702213075258944, 30.73407343073145, 4.713883370595925, 0.41785445342345773, 9.895897760331868, 23.078978424249655, 24.70230671873148, -28.70717994691324, -62.80839607927909, -59.78580240594249, -58.66179965578998, 22.19012607794575, -48.440119734599016, -34.813014520569666, 40.45052535780122], False)

# %%
# Setting variables for mutant activation
conductance, domain, all_is = ggsd.activationNa12("genActivation")
t_vec = ggsd.activationNa12("getTimesteps")
print(len(all_is))
print(len(all_is[0]))
print(len(t_vec))

times = []
for i in range(1,2800):
    times.append(t_vec[i])
# Out:
# 11
# 2799
# 2800

# %%
# Plotting mutant activation
plt.figure(dpi=150)
x_ticks = np.arange(0, 70, 5)
plt.xticks(x_ticks)
y_ticks = np.arange(-0.6, 0, 0.05)
plt.yticks(y_ticks)
for i in range(11):
    plt.plot(times, all_is[i])
plt.title('SCN8A Mutant, Activation')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[0])
plt.title('SCN8A Mutant, Activation -80 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[1])
plt.title('SCN8A Mutant, Activation -70 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[2])
plt.title('SCN8A Mutant, Activation -60 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[3])
plt.title('SCN8A Mutant, Activation -50 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[4])
plt.title('SCN8A Mutant, Activation -40 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[5])
plt.title('SCN8A Mutant, Activation -30 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[6])
plt.title('SCN8A Mutant, Activation -20 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[7])
plt.title('SCN8A Mutant, Activation -10 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[8])
plt.title('SCN8A Mutant, Activation 0 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[9])
plt.title('SCN8A Mutant, Activation 10 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[10])
plt.title('SCN8A Mutant, Activation 20 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
#Inactivation Analysis for WT
eh.change_params([26.16290131186328, -12.0101639601674, 27.196053413117404, 1.9469861884994089, 30.39306382908601, 0.0017907215184697748, 23.785261506905094, 4.92857518968744, -26.241045324281977, 8.086106428222955, 26.222313051782375, 2.5274060622463557, 0.16975232812307933, 12.616856862863338, 38.90427040109758, 23.1201609106394, -51.93850700235751, -59.251307951503705, -35.96725564810401, -42.12510135698245, 31.930246378525663, -65.11348041971499, -59.37453417493945, 27.768467864639433], False)
conductance, domain, all_is = ggsd.inactivationNa12("genInactivation")
t_vec = ggsd.inactivationNa12("getTimesteps")
print(len(all_is))
print(len(all_is[0]))
print(len(t_vec))

times = []
for i in range(1,3017):
    times.append(t_vec[i])
# Out:
# 14
# 3016
# 3017

# %%
#Plotting Inactivation for wild type
plt.figure(dpi=150)
x_ticks = np.arange(0, 600, 50)
plt.xticks(x_ticks)
y_ticks = np.arange(-0.6, 0, 0.05)
plt.yticks(y_ticks)
for i in range(14):
    plt.plot(times, all_is[i])
plt.title('SCN8A Wild Type, Inactivation')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[0])
plt.title('SCN8A Wild Type, Inactivation -130 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[1])
plt.title('SCN8A Wild Type, Inactivation -120 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[2])
plt.title('SCN8A Wild Type, Inactivation -110 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[3])
plt.title('SCN8A Wild Type, Inactivation -100 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[4])
plt.title('SCN8A Wild Type, Inactivation -90 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[5])
plt.title('SCN8A Wild Type, Inactivation -80 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[6])
plt.title('SCN8A Wild Type, Inactivation -70 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[7])
plt.title('SCN8A Wild Type, Inactivation -60 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[8])
plt.title('SCN8A Wild Type, Inactivation -50 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[9])
plt.title('SCN8A Wild Type, Inactivation -40 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[10])
plt.title('SCN8A Wild Type, Inactivation -30 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[11])
plt.title('SCN8A Wild Type, Inactivation -20 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[12])
plt.title('SCN8A Wild Type, Inactivation -10 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[13])
plt.title('SCN8A Wild Type, Inactivation 0 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
#Inactivation Analysis for Mutant
eh.change_params([84.84985991178564, -10.649745665278218, 18.94182073634545, 11.684636394881158, 23.956047692506168, 0.0017500368848982794, 8.018375873536707, 4.2822273182838835, -4.36607995239862, 9.702213075258944, 30.73407343073145, 4.713883370595925, 0.41785445342345773, 9.895897760331868, 23.078978424249655, 24.70230671873148, -28.70717994691324, -62.80839607927909, -59.78580240594249, -58.66179965578998, 22.19012607794575, -48.440119734599016, -34.813014520569666, 40.45052535780122], False)
conductance, domain, all_is = ggsd.inactivationNa12("genInactivation")
t_vec = ggsd.inactivationNa12("getTimesteps")
print(len(all_is))
print(len(all_is[0]))
print(len(t_vec))

times = []
for i in range(1,3017):
    times.append(t_vec[i])
# Out:
# 14
# 3016
# 3017

# %%
#Plotting inactivation for mutant
plt.figure(dpi=150)
x_ticks = np.arange(0, 600, 50)
plt.xticks(x_ticks)
y_ticks = np.arange(-0.6, 0, 0.05)
plt.yticks(y_ticks)
for i in range(14):
    plt.plot(times, all_is[i])
plt.title('SCN8A Mutant, Inactivation')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[0])
plt.title('SCN8A Mutant, Inactivation -130 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[1])
plt.title('SCN8A Mutant, Inactivation -120 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[2])
plt.title('SCN8A Mutant, Inactivation -110 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[3])
plt.title('SCN8A Mutant, Inactivation -100 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[4])
plt.title('SCN8A Mutant, Inactivation -90 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[5])
plt.title('SCN8A Mutant, Inactivation -80 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[6])
plt.title('SCN8A Mutant, Inactivation -70 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[7])
plt.title('SCN8A Mutant, Inactivation -60 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[8])
plt.title('SCN8A Mutant, Inactivation -50 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[9])
plt.title('SCN8A Mutant, Inactivation -40 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[10])
plt.title('SCN8A Mutant, Inactivation -30 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[11])
plt.title('SCN8A Mutant, Inactivation -20 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[12])
plt.title('SCN8A Mutant, Inactivation -10 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')

# %%
plt.plot(times, all_is[13])
plt.title('SCN8A Mutant, Inactivation 0 V')
plt.xlabel('Time (mS)')
plt.ylabel('Current(nA)')
# Out:
# Text(0, 0.5, 'Current(nA)')
