# %%
from exec_plot_choice import *
from fpdf import FPDF
import os
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

# %%
#choose which function to plot. 
#available options: Activation, Inactivation, RFI, Ramp, RecInact
plot_choice = "Activation"
new_params = {
    'Ena_na12mut': 55,
    'Rd_na12mut': .03,
    'Rg_na12mut': .01,
    'Rb_na12mut': .124,
    'Ra_na12mut': 0.4,
    'a0s_na12mut': 0.0003,
    'gms_na12mut': .02,
    'hmin_na12mut': .01,
    'mmin_na12mut': .02,
    'qinf_na12mut': 7,
    'q10_na12mut': 2,
    'qg_na12mut': 1.5,
    'qd_na12mut': .5,
    'qa_na12mut': 7.2,
    'smax_na12mut': 10,
    'sh_na12mut': 8,
    'thinf_na12mut': -45,
    'thi2_na12mut': -45,
    'thi1_na12mut': -45,
    'tha_na12mut': -30,
    'vvs_na12mut': 2,
    'vvh_na12mut': -58,
    'vhalfs_na12mut': -60,
    'zetas_na12mut': 12
    }

#renders the plot
exec_plot_choice(plot_choice, 'SCN8A_WT_opt_params.yaml', 'SCN8A_Mutant_opt_params.yaml', save_plots_as_pdf = True, 
                MT_name = "WT", mutant_name = "SCN8A_Mutant")
# Out:
# /Users/workbench/Applications/nrn/repo/Tel_Aviv_folder/curve_fitting.py:16: RuntimeWarning: overflow encountered in exp
#   return bottom +  ((top - bottom) / (1.0 + np.exp((v_half - x)/slope)))
