# %%
from exec_plot_choice import *
from fpdf import FPDF
import os
# %matplotlib inline
import mpld3
mpld3.enable_notebook()

# %%
#choose which function to plot. 
#available options: Activation, Inactivation, RFI, Ramp, RecInact
plot_choice = "Activation"
new_params = {
    'Ena_na16': 55,
    'Rd_na16': .03,
    'Rg_na16': .01,
    'Rb_na16': .124,
    'Ra_na16': 0.4,
    'a0s_na16': 0.0003,
    'gms_na16': .02,
    'hmin_na16': .01,
    'mmin_na16': .02,
    'qinf_na16': 7,
    'q10_na16': 2,
    'qg_na16': 1.5,
    'qd_na16': .5,
    'qa_na16': 7.2,
    'smax_na16': 10,
    'sh_na16': 8,
    'thinf_na16': -45,
    'thi2_na16': -45,
    'thi1_na16': -45,
    'tha_na16': -30,
    'vvs_na16': 2,
    'vvh_na16': -58,
    'vhalfs_na16': -60,
    'zetas_na16': 12
    }

#renders the plot
exec_plot_choice(plot_choice, 'SCN8A_WT_opt_params.yaml', 'SCN8A_Mutant_opt_params.yaml', save_plots_as_pdf = True, 
                MT_name = "WT", mutant_name = "Na16")
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17788/507810847.py in <module>
#      30
#      31 #renders the plot
# ---> 32 exec_plot_choice(plot_choice, 'SCN8A_WT_opt_params.yaml', 'SCN8A_Mutant_opt_params.yaml', save_plots_as_pdf = True,
#      33                 MT_name = "WT", mutant_name = "Na16")
#
# ~\Desktop\Simulating\Tel_Aviv_folder\exec_plot_choice.py in exec_plot_choice(plot_choice, WT_params_path, variant_params_path, save_plots_as_pdf, MT_name, mutant_name)
#      35         #updates parameters
#      36         if cur_params == "WT_params":
# ---> 37             change_params_dict_gen(WT_params)
#      38         if cur_params == "variant_params":
#      39             if variant_params:
#
# ~\Desktop\Simulating\Tel_Aviv_folder\eval_helper.py in change_params_dict_gen(new_params)
#     468     #change values of params
#     469     #print(new_params)
# --> 470     currh.Rd_na16= new_params['Rd']
#     471     currh.Rg_na16= new_params['Rg']
#     472     currh.Rb_na16= new_params['Rb']
#
# LookupError: 'Rd_na16' is not a defined hoc variable name.
