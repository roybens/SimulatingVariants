# %%
import numpy as np
import time
import generalized_genSim_shorten_time_HMM as ggsdHMM
import numpy as np
import curve_fitting as cf
import matplotlib.pyplot as plt
#import matplotlib.colors as colors
#import matplotlib.cm as cmx
from scipy import optimize, stats
import bluepyopt as bpop
import bluepyopt.deapext.algorithms as algo
import vclamp_evaluator_HMMtoHH as vcl_ev
import pickle
import time
from deap import tools
#from deap import base, creator
import multiprocessing
#import eval_helper as eh
#import scoring_functions_relative as sf
#import curve_fitting as cf
import generalized_genSim_shorten_time as ggsd
import eval_helper_na12mut8st as ehn
import HMM_plotter as plotter

# %%
p = [1.6145008130686316,
 1.2702355752969856,
 0.2856140201135051,
 2.000672353749617,
 159.19293105141264,
 0.8882089670901088,
 1.54307338742142,
 4.835533385345919,
 184.46766214071704,
 0.6193119174876813,
 8.851518497666747,
 0.07019281223744751,
 46.30970872218895,
 12.027049656918223,
 1.0303204433640094,
 0.05027526734333132,
 1791.9670172949814,
 1.3053734595552096,
 20.37380422148677,
 -9.174778056184731]

import eval_helper as eh
eh.change_params(p, scaled=False, is_HMM=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-2b18d002e66c> in <module>
#      21
#      22 import eval_helper as ehn
# ---> 23 ehn.change_params(p, scaled=False, is_HMM=True)
#
# ~\repo\SimVar_compiled_nogit\eval_helper.py in change_params(new_params, scaled, is_HMM)
#     244         else:
#     245             new_param_dict = make_params_dict(new_params, is_HMM=True)
# --> 246         change_params_dict(new_param_dict, is_HMM=True)
#     247
#     248     return
#
# ~\repo\SimVar_compiled_nogit\eval_helper.py in change_params_dict(new_params, is_HMM)
#     523         currh.zetas_na12mut= new_params['zetas_na12mut']
#     524     elif is_HMM:
# --> 525         act_object = ggsdHMM.Activation(channel_name='na12mut8st')
#     526         currh = act_object.h
#     527         soma = act_object.soma
#
# AttributeError: module 'generalized_genSim_shorten_time_HMM' has no attribute 'Activation'

# %%
plotter.make_inact_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-7fafed16d0d4> in <module>
# ----> 1 plotter.make_inact_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")
#
# ~\repo\SimVar_compiled_nogit\HMM_plotter.py in make_inact_plots(new_params, mutant_name, mutant_protocol_csv_name, param_values_wt, filename, is_HMM, channel_name)
#     196     plt.title(f'Inactivation: {mutant_name}')
#     197
# --> 198     set_param(param_values_wt, is_HMM)
#     199     wt_inact = module_name.Inactivation(channel_name = channel_name)
#     200     wt_inact.genInactivation()
#
# ~\repo\SimVar_compiled_nogit\HMM_plotter.py in set_param(param, is_HMM)
#       8 def set_param(param, is_HMM):
#       9     if is_HMM:
# ---> 10         eh.change_params(param, scaled=False, is_HMM=True)
#      11     else:
#      12         1/0
#
# ~\repo\SimVar_compiled_nogit\eval_helper.py in change_params(new_params, scaled, is_HMM)
#     244         else:
#     245             new_param_dict = make_params_dict(new_params, is_HMM=True)
# --> 246         change_params_dict(new_param_dict, is_HMM=True)
#     247
#     248     return
#
# ~\repo\SimVar_compiled_nogit\eval_helper.py in change_params_dict(new_params, is_HMM)
#     523         currh.zetas_na12mut= new_params['zetas_na12mut']
#     524     elif is_HMM:
# --> 525         act_object = ggsdHMM.Activation(channel_name='na12mut8st')
#     526         currh = act_object.h
#     527         soma = act_object.soma
#
# AttributeError: module 'generalized_genSim_shorten_time_HMM' has no attribute 'Activation'

# %%
plotter.make_act_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")
# Out:
# (actual, goal)
# activation v half: (0.0, -0.2155)
# activation slope: (1.0, 1.1159999999999999)

# %%
plotter.make_ramp_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")

# %%
wt_inact = h.Inactivation()
wt_inact.genInactivation()
wt_tau = wt_inact.plotInactivation_Tau_0mV_plt(plt, 'black')
wt_per_cur = find_persistent_current()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4036/4082071806.py in <module>
# ----> 1 wt_inact = h.Inactivation()
#       2 wt_inact.genInactivation()
#       3 wt_tau = wt_inact.plotInactivation_Tau_0mV_plt(plt, 'black')
#       4 wt_per_cur = find_persistent_current()
#
# NameError: name 'h' is not defined

# %%
wt_act = ggsdHMM.Activation()
wt_act.genActivation()
# (formatted_v_half, formatted_gv_slope)
act_v_half_wt, act_slope_wt = wt_act.plotActivation_VGnorm_plt(plt, 'black')
