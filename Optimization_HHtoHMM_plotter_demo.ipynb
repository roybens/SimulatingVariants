# %%
import numpy as np
import time
import generalized_genSim_shorten_time_HMM as ggsdHMM
import numpy as np
import curve_fitting as cf
import matplotlib.pyplot as plt
#import matplotlib.colors as colors
#import matplotlib.cm as cmx
from scipy import optimize, stats
import bluepyopt as bpop
import bluepyopt.deapext.algorithms as algo
import vclamp_evaluator_HMMtoHH as vcl_ev
import pickle
import time
from deap import tools
#from deap import base, creator
import multiprocessing
#import eval_helper as eh
#import scoring_functions_relative as sf
#import curve_fitting as cf
import generalized_genSim_shorten_time as ggsd
import eval_helper_na12mut8st as ehn
import HMM_plotter as plotter

# %%
p = [1.6145008130686316,
 1.2702355752969856,
 0.2856140201135051,
 2.000672353749617,
 159.19293105141264,
 0.8882089670901088,
 1.54307338742142,
 4.835533385345919,
 184.46766214071704,
 0.6193119174876813,
 8.851518497666747,
 0.07019281223744751,
 46.30970872218895,
 12.027049656918223,
 1.0303204433640094,
 0.05027526734333132,
 1791.9670172949814,
 1.3053734595552096,
 20.37380422148677,
 -9.174778056184731]

p_1 = [54.34262293669414,
  1.7302978945812297,
  -0.07354994084897437,
  1.0274622191031129,
  -0.8315449008917479,
  0.0005189328097015933,
  -1.0242349982611,
  -3.487314253755478,
  -3.9000553081113507,
  6.7511166832754945,
  6.419276141835943,
  1.599793752408494,
  0.9768243489372747,
  10.86215735486871,
  14.982509993547737,
  6.677141890249841,
  -45.539330456551454,
  -45.178524295081786,
  -48.92012572985329,
  -25.443618232743145,
  4.693675132247042,
  -56.848909365593485,
  -61.57903784353114,
  16.032251193214464]

import eval_helper as eh
eh.change_params(p, scaled=False, is_HMM=True)

# %%
plotter.make_inact_plots(p_1, "A427D", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut8st")
# Out:
# Couldn't fit curve to inactivation.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35452/2358695414.py in <module>
# ----> 1 plotter.make_inact_plots(p_1, "A427D", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut8st")
#
# ~\desktop\simulating\HMM_plotter.py in make_inact_plots(new_params, mutant_name, mutant_protocol_csv_name, param_values_wt, filename, is_HMM, channel_name)
#     207     mut_inact = module_name.Inactivation(channel_name = channel_name)
#     208     mut_inact.genInactivation()
# --> 209     inact_v_half_mut, inact_slope_mut = mut_inact.plotInactivation_VInormRelation_plt(plt, 'red')
#     210
#     211
#
# ~\desktop\simulating\generalized_genSim_shorten_time_HMM.py in plotInactivation_VInormRelation_plt(self, plt, color)
#     554             diff = 0.5
#     555         plt.plot(self.v_vec, self.inorm_vec, 'o', c=color)
# --> 556         ssi_slope, v_half, top, bottom = cf.calc_inact_obj(self.channel_name, is_HMM = True)
#     557         formatted_ssi_slope = np.round(ssi_slope, decimals=2)
#     558         formatted_v_half = np.round(v_half, decimals=2)
#
# ValueError: too many values to unpack (expected 4)

# %%
plotter.make_act_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")
# Out:
# (actual, goal)
# activation v half: (0.0, -0.2155)
# activation slope: (1.0, 1.1159999999999999)

# %%
plotter.make_recov_plots(p_1, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut8st")
# Out:
# C:\Users\ccfla\desktop\simulating\generalized_genSim_shorten_time_HMM.py:887: RuntimeWarning: divide by zero encountered in log
#   tau = -h.tstop / np.log(-RF_t + 1)
# C:\Users\ccfla\AppData\Local\Programs\Python\Python39\lib\site-packages\scipy\optimize\minpack.py:833: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
plotter.make_ramp_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")

# %%
wt_inact = h.Inactivation()
wt_inact.genInactivation()
wt_tau = wt_inact.plotInactivation_Tau_0mV_plt(plt, 'black')
wt_per_cur = find_persistent_current()

# %%
wt_act = ggsdHMM.Activation()
wt_act.genActivation()
# (formatted_v_half, formatted_gv_slope)
act_v_half_wt, act_slope_wt = wt_act.plotActivation_VGnorm_plt(plt, 'black')

# %%
plotter.make_UDB20_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM=True,
                       channel_name="na12mut")
