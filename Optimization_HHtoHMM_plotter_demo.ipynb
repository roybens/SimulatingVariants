# %%
import numpy as np
import time
import generalized_genSim_shorten_time_HMM as ggsdHMM
import numpy as np
import curve_fitting as cf
import matplotlib.pyplot as plt
#import matplotlib.colors as colors
#import matplotlib.cm as cmx
from scipy import optimize, stats
import bluepyopt as bpop
import bluepyopt.deapext.algorithms as algo
import vclamp_evaluator_HMMtoHH as vcl_ev
import pickle
import time
from deap import tools
#from deap import base, creator
import multiprocessing
#import eval_helper as eh
#import scoring_functions_relative as sf
#import curve_fitting as cf
import generalized_genSim_shorten_time as ggsd
import eval_helper_na12mut8st as ehn
import HMM_plotter as plotter
# Out:
# Reached import hoc
# Reached import neuron.hoc

# %%
p = [1.6145008130686316,
 1.2702355752969856,
 0.2856140201135051,
 2.000672353749617,
 159.19293105141264,
 0.8882089670901088,
 1.54307338742142,
 4.835533385345919,
 184.46766214071704,
 0.6193119174876813,
 8.851518497666747,
 0.07019281223744751,
 46.30970872218895,
 12.027049656918223,
 1.0303204433640094,
 0.05027526734333132,
 1791.9670172949814,
 1.3053734595552096,
 20.37380422148677,
 -9.174778056184731]

import eval_helper as eh
eh.change_params(p, scaled=False, is_HMM=True)

# %%
plotter.make_inact_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7fafed16d0d4> in <module>
# ----> 1 plotter.make_inact_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")
#
# NameError: name 'plotter' is not defined

# %%
plotter.make_act_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")

# %%
wt_inact = h.Inactivation()
wt_inact.genInactivation()
wt_tau = wt_inact.plotInactivation_Tau_0mV_plt(plt, 'black')
wt_per_cur = find_persistent_current()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c843aca7915d> in <module>
# ----> 1 wt_inact = h.Inactivation()
#       2 wt_inact.genInactivation()
#       3 wt_tau = wt_inact.plotInactivation_Tau_0mV_plt(plt, 'black')
#       4 wt_per_cur = find_persistent_current()
#
# NameError: name 'h' is not defined

# %%
wt_act = ggsdHMM.Activation()
wt_act.genActivation()
# (formatted_v_half, formatted_gv_slope)
act_v_half_wt, act_slope_wt = wt_act.plotActivation_VGnorm_plt(plt, 'black')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-8574b33f9392> in <module>
#       1 wt_act = ggsdHMM.Activation()
# ----> 2 wt_act.genActivation()
#       3 # (formatted_v_half, formatted_gv_slope)
#       4 act_v_half_wt, act_slope_wt = wt_act.plotActivation_VGnorm_plt(plt, 'black')
#       5
#
# /global/u1/m/mikelam/SimulatingVariants/generalized_genSim_shorten_time_HMM.py in genActivation(self)
#     248
#     249             # calculate normalized peak conductance
# --> 250             self.gnorm_vec = self.findG(self.v_vec, self.ipeak_vec)
#     251
#     252         return self.gnorm_vec, self.v_vec, self.all_is
#
# /global/u1/m/mikelam/SimulatingVariants/generalized_genSim_shorten_time_HMM.py in findG(self, v_vec, ipeak_vec)
#     217
#     218         self.vrev = stats.linregress(lin_i, lin_v).intercept
# --> 219         Gmax, self.v_half, self.s = optimize.curve_fit(cf.boltzmann, v_vec, ipeak_vec)[0]
#     220
#     221         # find normalized conductances at each voltage
#
# ValueError: too many values to unpack (expected 3)

# %%
plotter.make_recov_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-1ce790f8ebab> in <module>
# ----> 1 plotter.make_recov_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")
#
# /global/u1/m/mikelam/SimulatingVariants/HMM_plotter.py in make_recov_plots(new_params, mutant_name, mutant_protocol_csv_name, param_values_wt, filename, is_HMM, channel_name)
#     291     wt_recov = module_name.RFI(channel_name=channel_name)
#     292     wt_recov.genRecInactTau()
# --> 293     wt_recov.plotAllRFI(ax1, ax2, ax3, ax4)
#     294
#     295
#
# /global/u1/m/mikelam/SimulatingVariants/generalized_genSim_shorten_time_HMM.py in plotAllRFI(self, ax1, ax2, ax3, ax4)
#     967         """
#     968         self.plotRFI_VInormRelation(ax1)
# --> 969         self.plotRFI_LogVInormRelation(ax2)
#     970         self.plotRFI_TimeVRelation(ax3)
#     971         self.plotRFI_TCurrDensityRelation(ax4)
#
# TypeError: plotRFI_LogVInormRelation() takes 1 positional argument but 2 were given
