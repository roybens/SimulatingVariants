# %%
import numpy as np
import time
import generalized_genSim_shorten_time_HMM as ggsdHMM
import numpy as np
import curve_fitting as cf
import matplotlib.pyplot as plt
#import matplotlib.colors as colors
#import matplotlib.cm as cmx
from scipy import optimize, stats
import bluepyopt as bpop
import bluepyopt.deapext.algorithms as algo
import vclamp_evaluator_HMMtoHH as vcl_ev
import pickle
import time
from deap import tools
#from deap import base, creator
import multiprocessing
#import eval_helper as eh
#import scoring_functions_relative as sf
#import curve_fitting as cf
import generalized_genSim_shorten_time as ggsd
import eval_helper_na12mut8st as ehn
import HMM_plotter as plotter

# %%
p = [1.6145008130686316,
 1.2702355752969856,
 0.2856140201135051,
 2.000672353749617,
 159.19293105141264,
 0.8882089670901088,
 1.54307338742142,
 4.835533385345919,
 184.46766214071704,
 0.6193119174876813,
 8.851518497666747,
 0.07019281223744751,
 46.30970872218895,
 12.027049656918223,
 1.0303204433640094,
 0.05027526734333132,
 1791.9670172949814,
 1.3053734595552096,
 20.37380422148677,
 -9.174778056184731]

p_1 = [251.13271452152281, 0.10437122947276659, 0.12142361782233926, 0.7963678123046358, 87.7432499817526, 0.2181806981554227, 0.9354158757810526, 0.13560383511717164, 495.71666612993937, 0.015815418422276677, 6.354865560447292, 0.0038834888710251834, 12.863770137241847, 2.806668955412046, 0.6863666713200415, 3.9607925155942967, 1519.7510537871524, 0.15726941262882127, 9.740061519725462, 2.449259386085319]

import eval_helper as eh
eh.change_params(p, scaled=False, is_HMM=True)

# %%
plotter.make_inact_plots(p_1, "A427D", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut8st")

# %%
plotter.make_act_plots(p, "A427D", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut8st")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-98bcb8ac6797> in <module>
# ----> 1 plotter.make_act_plots(p, "A427D", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut8st")
#       2
#
# /global/u1/m/mikelam/SimulatingVariants/HMM_plotter.py in make_act_plots(new_params, mutant_name, mutant_protocol_csv_name, param_values_wt, filename, is_HMM, channel_name)
#     166     plt.text(0.1,0.7,"activation v half: " + str((act_v_half_mut - act_v_half_wt , goal_dict['dv_half_act'])))
#     167     plt.text(0.1,0.5,"activation slope: " + str((act_slope_mut/act_slope_wt , goal_dict['gv_slope']/100)))
# --> 168     plt.text(0.1,0.3,"peak amp: " + str((mut_peak_amp/wt_peak_amp , peak_amp_dict[mutant_name])))
#     169
#     170
#
# KeyError: 'A427D'

# %%
plotter.make_act_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")
# Out:
# (actual, goal)
# activation v half: (0.0, -0.2155)
# activation slope: (1.0, 1.1159999999999999)

# %%
plotter.make_recov_plots(p_1, "A427D", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut8st")

# %%
plotter.make_ramp_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")

# %%
wt_inact = h.Inactivation()
wt_inact.genInactivation()
wt_tau = wt_inact.plotInactivation_Tau_0mV_plt(plt, 'black')
wt_per_cur = find_persistent_current()

# %%
wt_act = ggsdHMM.Activation()
wt_act.genActivation()
# (formatted_v_half, formatted_gv_slope)
act_v_half_wt, act_slope_wt = wt_act.plotActivation_VGnorm_plt(plt, 'black')

# %%
plotter.make_UDB20_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM=True,
                       channel_name="na12mut")
