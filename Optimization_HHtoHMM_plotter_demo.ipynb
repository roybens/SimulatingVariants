# %%
import numpy as np
import time
import generalized_genSim_shorten_time_HMM as ggsdHMM
import numpy as np
import curve_fitting as cf
import matplotlib.pyplot as plt
#import matplotlib.colors as colors
#import matplotlib.cm as cmx
from scipy import optimize, stats
import bluepyopt as bpop
import bluepyopt.deapext.algorithms as algo
import vclamp_evaluator_HMMtoHH as vcl_ev
import pickle
import time
from deap import tools
#from deap import base, creator
import multiprocessing
#import eval_helper as eh
#import scoring_functions_relative as sf
#import curve_fitting as cf
import generalized_genSim_shorten_time as ggsd
import eval_helper_na12mut8st as ehn
import HMM_plotter as plotter

# %%
p = [1.6145008130686316,
 1.2702355752969856,
 0.2856140201135051,
 2.000672353749617,
 159.19293105141264,
 0.8882089670901088,
 1.54307338742142,
 4.835533385345919,
 184.46766214071704,
 0.6193119174876813,
 8.851518497666747,
 0.07019281223744751,
 46.30970872218895,
 12.027049656918223,
 1.0303204433640094,
 0.05027526734333132,
 1791.9670172949814,
 1.3053734595552096,
 20.37380422148677,
 -9.174778056184731,
    10]

p_1 = [251.13271452152281, 0.10437122947276659, 0.12142361782233926, 0.7963678123046358, 87.7432499817526, 0.2181806981554227, 0.9354158757810526, 0.13560383511717164, 495.71666612993937, 0.015815418422276677, 6.354865560447292, 0.0038834888710251834, 12.863770137241847, 2.806668955412046, 0.6863666713200415, 3.9607925155942967, 1519.7510537871524, 0.15726941262882127, 9.740061519725462, 2.449259386085319]

#import eval_helper as eh
#eh.change_params(p, scaled=False, is_HMM=True)

# %%
plotter.make_inact_plots(p, "A427D", "./csv_files/mutant_protocols.csv", None, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut8st")

# %%
plotter.make_act_plots(p, "A427D", "./csv_files/mutant_protocols.csv", None, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut8st")
# Out:
# /global/u2/r/roybens/SimulatingVariants/generalized_genSim_shorten_time_HMM.py:216: RuntimeWarning: overflow encountered in exp
#   return Gmax * (vm - self.vrev) / (1 + np.exp((v_half - vm) / s))
# /usr/lib/python3/dist-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /global/u2/r/roybens/SimulatingVariants/generalized_genSim_shorten_time_HMM.py:224: RuntimeWarning: overflow encountered in exp
#   norm_g.append(1 / (1 + np.exp(-(volt - self.v_half) / self.s)))
# /global/u2/r/roybens/SimulatingVariants/generalized_genSim_shorten_time_HMM.py:216: RuntimeWarning: overflow encountered in exp
#   return Gmax * (vm - self.vrev) / (1 + np.exp((v_half - vm) / s))
# /usr/lib/python3/dist-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /global/u2/r/roybens/SimulatingVariants/generalized_genSim_shorten_time_HMM.py:224: RuntimeWarning: overflow encountered in exp
#   norm_g.append(1 / (1 + np.exp(-(volt - self.v_half) / self.s)))
# /global/u2/r/roybens/SimulatingVariants/generalized_genSim_shorten_time_HMM.py:216: RuntimeWarning: overflow encountered in exp
#   return Gmax * (vm - self.vrev) / (1 + np.exp((v_half - vm) / s))
# /usr/lib/python3/dist-packages/scipy/optimize/minpack.py:794: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',
# /global/u2/r/roybens/SimulatingVariants/generalized_genSim_shorten_time_HMM.py:224: RuntimeWarning: overflow encountered in exp
#   norm_g.append(1 / (1 + np.exp(-(volt - self.v_half) / self.s)))
# (actual, goal)
# activation v half: (0.0, -3.789)
# activation slope: (1.0, 1.344)

# %%
plotter.make_recov_plots(p, "A427D", "./csv_files/mutant_protocols.csv", None, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut8st")
# Out:
# 14 14 [0.16777881492637187, 0.23423822902822855, 0.404953707511157, 0.6157559719872292, 0.8166967274163197, 0.9936503804026012, 0.9999092883443096, 0.9999891363514583, 0.9999891850965543, 0.9999891851073975, 0.9999891851073973, 0.9999891851073975, 0.9999891851073988, 0.9999891851073978]

# %%
plotter.make_ramp_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM = True, channel_name = "na12mut")

# %%
wt_act = ggsdHMM.Activation()
wt_act.genActivation()
# (formatted_v_half, formatted_gv_slope)
act_v_half_wt, act_slope_wt = wt_act.plotActivation_VGnorm_plt(plt, 'black')

# %%
plotter.make_UDB20_plots(p, "K1260E", "./csv_files/mutant_protocols.csv", p, "./Plots_Folder/jinan_test.pdf", is_HMM=True,
                       channel_name="na12mut")
